# %% [markdown]
# # About
#
# - `Title:` "Lower and Upper Bounds on the VC-Dimension of Tensor Network Models"
# - `Main Author:` Behnoush Khavari
# - `Source:` [ArXiv](https://arxiv.org/abs/2106.11827)
# - `Publish Date:` 22-06-2021
# - `Reviewed Date:` 22-11-2021
#
# ## Citation
#
# ```latex
# @article{khavari2021lower,
#   title={Lower and Upper Bounds on the VC-Dimension of Tensor Network Models},
#   author={Khavari, Behnoush and Rabusseau, Guillaume},
#   journal={arXiv preprint arXiv:2106.11827},
#   year={2021}
# }
# ```

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# %env JAX_ENABLE_X64=1
# %env JAX_PLATFORM_NAME=cpu
# Out:
# env: JAX_ENABLE_X64=1
# env: JAX_PLATFORM_NAME=cpu

# %%
import jax
import jax.numpy as jnp
from jax import jit, grad

# %%
from typing import Any

PRNGKeyArray = Any # type alias

# %%
import matplotlib.pyplot as plt

plt.style.use('classic')
plt.rcParams['xtick.labelsize'] = 16
plt.rcParams['ytick.labelsize'] = 16

# %%
import pickle
import time
import itertools
from functools import reduce

# %% [markdown]
# # Helpers

# %%
from collections import defaultdict

def idict():
    """Infinitely nested dict"""
    return defaultdict(idict)

def idict2dict(dic):
    if isinstance(dic, defaultdict):
        dic = {k: idict2dict(v) for k, v in dic.items()}
    return dic

# %%
import os
import pickle

def save_pkl(file_path, data):
    dir_name = os.path.dirname(file_path)
    if not os.path.exists(dir_name):
        os.makedirs(dir_name)
    with open(file_path, 'wb') as f:
        pickle.dump(data, f)

# %% [markdown]
# # Random Data Generation

# %%
def random_mps(
    key: PRNGKeyArray,
    size: int,
    local_dim: int,
    bond_dim: int,
    dtype=jnp.float64):
    """
    Generate a random MPS where each core tensor
    is drawn i.i.d. from a uniform distribution 
    between -1 and 1.

    Input:
    ------
    key:        The random key.
    size:       The size (length) of an MPS.
    local_dim:  The local dimension size.
    bond_dim:   The bond dimension size.
    dtype:      The type of data to return.
    """
    # initialize MPS data collection
    mps = []
     
    for i in range(size):
        key, _ = jax.random.split(key)
        if i == 0:  # left most tensor
            tensor = jax.random.uniform(
                key, shape=(1, local_dim, bond_dim), minval=-1, maxval=1, dtype=dtype)
        elif i == size-1:  # right most tensor
            tensor = jax.random.uniform(
                key, shape=(bond_dim, local_dim, 1), minval=-1, maxval=1, dtype=dtype)
        else:  # middle tensors
            tensor = jax.random.uniform(
                key, shape=(bond_dim, local_dim, bond_dim), minval=-1, maxval=1, dtype=dtype)
        mps.append(tensor)

    return mps

# %%
def random_sample(
    key: PRNGKeyArray,
    size: int,
    local_dim: int,
    n_factors: int,
    dtype=jnp.float64):
    """
    Generate random data samples where components
    corrsponding to MPS tensors are drawn i.i.d. 
    from a normal distribution.

    Input:
    ------
    key:        The random key.
    size:       The sample size.
    local_dim:  The dimension of each sample.
    n_factors:  The number of factors (equal to the MPS size).
    dtype:      The type of data to return.
    """
    # initialize the collection
    samples = []
        
    for _ in range(size):
        x = []  # collects the components of a single sample 
        for _ in range(n_factors):
            key, _ = jax.random.split(key, num=2)
            x.append(
                jax.random.normal(
                    key, 
                    shape=(local_dim,), 
                    dtype=dtype)
            )
        samples.append(x)

    return jnp.asarray(samples)

# %%
def fully_contract(mps):
    """Fully contract the MPS with its conjugate."""
    tensors = [jnp.einsum('pqr,uqv->purv', t, t.conj()) for t in mps]
    res = reduce(lambda x,y: jnp.einsum('purv,rvts->puts', x,y), tensors)
    return res.squeeze()

def mps_norm(mps):
    return fully_contract(mps)

def contract(params, samples):
    """Contract MPS with data"""
    
    def _multiply(params, x):
        """
        Contract an individual core tensor with a data component.
        [p] --W-- [r]
          [q] |       = [p] --(Wx)-- [r]
              x
        """
        tensors = [
            jnp.einsum('pqr,q->pr', w, xi)
            for w, xi in zip(params, x)
        ]
        # full reduction (contraction)
        return reduce(lambda x, y: x @ y, tensors)
    
    prods = jnp.asarray([
        _multiply(params, s)
        for s in samples
    ])
    
    return prods.squeeze()

# %%
# key = jax.random.PRNGKey(0)
# mps = random_mps(key, 3, 3, 5)

# norm_1 = norm_squared(mps).item()

# a = jnp.tensordot(mps[0], mps[0].conj(), axes=((1),(1)))
# b = jnp.tensordot(mps[1], mps[1].conj(), axes=((1),(1)))
# c = jnp.tensordot(mps[2], mps[2].conj(), axes=((1),(1)))

# ab  = jnp.tensordot(a, b, axes=((1,3),(0,2)))
# abc = jnp.tensordot(ab, c, axes=((2,3),(0,2)))

# norm_2 = abc.item()

# import numpy as np
# from ncon import ncon

# mps = list(map(np.array, mps))
# TensorArray = [mps[0], mps[0].conj(), mps[1], mps[1].conj(), mps[2], mps[2].conj()]
# IndexArray = [[-1,1,2],[-2,1,4],[2,3,6],[4,3,8],[6,5,-4],[8,5,-3]]
# norm_3 = ncon(TensorArray, IndexArray).item()

# print (norm_1, norm_2, norm_3)

# %% [markdown]
# ## Constants

# %%
# PRNG seed
SEED = 161803

# model size (MPS_SIZE * LOCAL_DIM + BOND_DIM = TRAIN_SIZE)
MPS_SIZE = 4
LOCAL_DIM = 4
BOND_DIM = 6

# data sample
TRAIN_SIZE = 100
TEST_SIZE  = 200

# training params
LEARNING_RATE = 1e-1

# max num of iterations
MAX_STEPS = int(5e4)

# APPROX RANK
APPROX_RANK = list(range(2,11,2))

# NOISE MODEL
PERCENT_NOISE = [0.1, 0.25, 0.5, 1, 5, 10] # noise level in percentages to the data std

# SAVE/PRINT after that many epochs
SAVE_AFTER_EPOCHS = 50

# %%
def make_dirs(root_dir, noise_level):
    # A timestamp used in the experiments to store data
    time_stamp = time.strftime('%Y%m%d', time.localtime())
    exp_dir = os.path.join(f'{root_dir}/{time_stamp}-noise-{noise_level}')
    lrn_dir = os.path.join(exp_dir, 'learning')  # stores the learning progress
    res_dir = os.path.join(exp_dir, 'results')   # stores the experimenal results

    for d in (lrn_dir, res_dir):
        if not os.path.isdir(d):
            os.makedirs(d)
        elif len(os.listdir(d)) > 0:
            raise FileExistsError(f'Directory {d} is not empty!')
        else:
            pass
        
    return exp_dir, lrn_dir, res_dir

# %%
def save_settings(settings_file):
    if not os.path.exists(settings_file):
        # storing for records
        with open(settings_file, 'w') as f:
            txt = f"""
SEED = {SEED}

# model size (MPS_SIZE * LOCAL_DIM + BOND_DIM = TRAIN_SIZE)
MPS_SIZE = {MPS_SIZE}
LOCAL_DIM = {LOCAL_DIM}
BOND_DIM = {BOND_DIM}

# data sample
TRAIN_SIZE = {TRAIN_SIZE}
TEST_SIZE = {TEST_SIZE}

# training params
LEARNING_RATE = {LEARNING_RATE}

# max num of iterations
MAX_STEPS = {MAX_STEPS}

# APPROX RANK
APPROX_RANK = {APPROX_RANK}

# NOISE MODEL
PERCENT_NOISE = {PERCENT_NOISE}
"""
            f.write(txt)
    else:
        raise FileExistsError(f'File {settings_file} already exists - STOP!')

# %% [markdown]
# ## Loss function

# %%
@jit
def loss(params, data):
    inputs, targets = data
    outputs = contract(params, inputs)
    err = jnp.power(targets - outputs, 2)
    return 0.5 * jnp.mean(jnp.log(err + 0.5))
    # return jnp.sqrt(0.5 * jnp.mean(err))

# computing the gradient wrt the loss
grad_loss = jit(grad(loss, argnums=0))

def line_search(params, data, lr=1e-2, beta=1e-6):
    """Armijo line search"""
    grads = grad_loss(params, data)
    while True:
        params_new = [
            p - lr * g 
            for p, g in zip(params, grads)
        ]
        if loss(params_new, data) > loss(params, data):#  - beta * lr * mps_norm(grads):
            lr /= 2
        else:
            break
    return params_new

# %% [markdown]
# ## Data Prep

# %%
key = jax.random.PRNGKey(SEED)

# %%
# Spliting the key
key_mps, key_data, key_noise, key_run = jax.random.split(key, num=4)

# %%
# target MPS model
true_params = random_mps(key_mps, size=MPS_SIZE, local_dim=LOCAL_DIM, bond_dim=BOND_DIM)

# generate samples
data = random_sample(key_data, size=TRAIN_SIZE+TEST_SIZE, local_dim=LOCAL_DIM, n_factors=MPS_SIZE)

# train/test split
train_data, test_data = data[:TRAIN_SIZE], data[TRAIN_SIZE:]

# test targets
test_targets = contract(true_params, test_data)

# %% [markdown]
# ## Execution

# %%
def gauss_noise(key, sample_size, scale=1.0):
    return scale * jax.random.normal(key, shape=(sample_size,))

# %%
root_dir = './experiment'

for perc_noise in PERCENT_NOISE:
    
    # timer
    tic = time.time()
    
    # noise model
    noise = gauss_noise(key_noise, sample_size=TRAIN_SIZE, scale=perc_noise * jnp.std(train_data))

    # generate outputs by contracting MPS with data
    train_targets = contract(true_params, train_data) + noise

    # making exp directory
    exp_dir, lrn_dir, res_dir = make_dirs(root_dir, perc_noise)
    
    # storing the settings into a file
    settings_file = os.path.join(exp_dir, 'settings.txt')
    save_settings(settings_file)

    # storing results
    results = idict()

    ref_loss_tr = 1e6
    ref_loss_te = 1e6

    for approx_rank in APPROX_RANK:
            
        print(f"Approximation rank: {approx_rank}")
        print('='*50)
        
        loss_tr = []
        loss_te = []
        
        # initialize MPS parameters randomly but different SEED than was used for true params
        params = random_mps(key_run, size=MPS_SIZE, local_dim=LOCAL_DIM, bond_dim=approx_rank)

        # counter
        counter = itertools.count()
        step = next(counter)
            
        # Looping until condition
        while step < MAX_STEPS:

            # update parameters
            params_new = line_search(params, (train_data, train_targets), LEARNING_RATE)
                    
            # Generalization risk
            l_tr = loss(params_new, (train_data, train_targets))
            l_te = loss(params_new, (test_data, test_targets))
                    
            # printing epochs
            if step % SAVE_AFTER_EPOCHS == 0:
                
                # storing errors for statistics (saving memory)
                loss_tr.append(l_tr)
                loss_te.append(l_te)
                
                print(f'Step: {step:<15} \t|\t Train loss: {l_tr:<10.3f} \t|\t Test loss: {l_te:<10.3f}')
                
                # storing parameters during training
                file_path = os.path.join(lrn_dir, f'./approx_rank_{approx_rank}/step_{step}.pkl')
                save_pkl(file_path, params)

            # update the parameters
            params = params_new

            # advance the counter
            step = next(counter)
            
            # update the reference
            ref_loss_tr = l_tr
            ref_loss_te = l_te
            
        # storing train/test loss
        results["train"][approx_rank] = loss_tr
        results["test"][approx_rank] = loss_te

        print('-'*100)
        print(f'Time for rank {approx_rank}: {(time.time() - tic):0.2f} sec')
        print(f'Train loss: {ref_loss_tr:0.2f}')
        print(f'Test loss: {ref_loss_te:0.2f}')
        print('='*100)
        
        file_path = os.path.join(res_dir, 'loss.pkl')
        save_pkl(file_path, idict2dict(results))
# Out:
# Approximation rank: 2
# ==================================================
# Step: 0               	|	 Train loss: 1.915      	|	 Test loss: 2.012
# Step: 50              	|	 Train loss: 1.739      	|	 Test loss: 2.015
# Step: 100             	|	 Train loss: 1.688      	|	 Test loss: 1.987
# Step: 150             	|	 Train loss: 1.651      	|	 Test loss: 1.975
# Step: 200             	|	 Train loss: 1.641      	|	 Test loss: 1.977
# Step: 250             	|	 Train loss: 1.632      	|	 Test loss: 1.979
# Step: 300             	|	 Train loss: 1.621      	|	 Test loss: 1.979
# Step: 350             	|	 Train loss: 1.612      	|	 Test loss: 1.978
# Step: 400             	|	 Train loss: 1.607      	|	 Test loss: 1.977
# Step: 450             	|	 Train loss: 1.602      	|	 Test loss: 1.976
# Step: 500             	|	 Train loss: 1.597      	|	 Test loss: 1.974
# Step: 550             	|	 Train loss: 1.591      	|	 Test loss: 1.972
# Step: 600             	|	 Train loss: 1.584      	|	 Test loss: 1.969
# Step: 650             	|	 Train loss: 1.571      	|	 Test loss: 1.965
# Step: 700             	|	 Train loss: 1.564      	|	 Test loss: 1.966
# Step: 750             	|	 Train loss: 1.560      	|	 Test loss: 1.966
# Step: 800             	|	 Train loss: 1.557      	|	 Test loss: 1.966
# Step: 850             	|	 Train loss: 1.553      	|	 Test loss: 1.966
# Step: 900             	|	 Train loss: 1.549      	|	 Test loss: 1.965
# Step: 950             	|	 Train loss: 1.544      	|	 Test loss: 1.965
# Step: 1000            	|	 Train loss: 1.538      	|	 Test loss: 1.965
# Step: 1050            	|	 Train loss: 1.526      	|	 Test loss: 1.970
# Step: 1100            	|	 Train loss: 1.510      	|	 Test loss: 1.976
# Step: 1150            	|	 Train loss: 1.498      	|	 Test loss: 1.985
# Step: 1200            	|	 Train loss: 1.485      	|	 Test loss: 1.994
# Step: 1250            	|	 Train loss: 1.477      	|	 Test loss: 2.001
# Step: 1300            	|	 Train loss: 1.468      	|	 Test loss: 2.006
# Step: 1350            	|	 Train loss: 1.458      	|	 Test loss: 2.018
# Step: 1400            	|	 Train loss: 1.421      	|	 Test loss: 2.042
# Step: 1450            	|	 Train loss: 1.380      	|	 Test loss: 2.052
# Step: 1500            	|	 Train loss: 1.362      	|	 Test loss: 2.055
# Step: 1550            	|	 Train loss: 1.347      	|	 Test loss: 2.063
# Step: 1600            	|	 Train loss: 1.328      	|	 Test loss: 2.073
# Step: 1650            	|	 Train loss: 1.319      	|	 Test loss: 2.081
# Step: 1700            	|	 Train loss: 1.312      	|	 Test loss: 2.085
# Step: 1750            	|	 Train loss: 1.306      	|	 Test loss: 2.088
# Step: 1800            	|	 Train loss: 1.300      	|	 Test loss: 2.092
# Step: 1850            	|	 Train loss: 1.293      	|	 Test loss: 2.097
# Step: 1900            	|	 Train loss: 1.285      	|	 Test loss: 2.102
# Step: 1950            	|	 Train loss: 1.270      	|	 Test loss: 2.106
# Step: 2000            	|	 Train loss: 1.249      	|	 Test loss: 2.109
# Step: 2050            	|	 Train loss: 1.245      	|	 Test loss: 2.108
# Step: 2100            	|	 Train loss: 1.243      	|	 Test loss: 2.107
# Step: 2150            	|	 Train loss: 1.240      	|	 Test loss: 2.106
# Step: 2200            	|	 Train loss: 1.236      	|	 Test loss: 2.107
# Step: 2250            	|	 Train loss: 1.230      	|	 Test loss: 2.112
# Step: 2300            	|	 Train loss: 1.218      	|	 Test loss: 2.121
# Step: 2350            	|	 Train loss: 1.216      	|	 Test loss: 2.128
# Step: 2400            	|	 Train loss: 1.213      	|	 Test loss: 2.136
# Step: 2450            	|	 Train loss: 1.209      	|	 Test loss: 2.143
# Step: 2500            	|	 Train loss: 1.196      	|	 Test loss: 2.154
# Step: 2550            	|	 Train loss: 1.194      	|	 Test loss: 2.155
# Step: 2600            	|	 Train loss: 1.192      	|	 Test loss: 2.154
# Step: 2650            	|	 Train loss: 1.189      	|	 Test loss: 2.153
# Step: 2700            	|	 Train loss: 1.188      	|	 Test loss: 2.153
# Step: 2750            	|	 Train loss: 1.186      	|	 Test loss: 2.154
# Step: 2800            	|	 Train loss: 1.184      	|	 Test loss: 2.155
# Step: 2850            	|	 Train loss: 1.182      	|	 Test loss: 2.157
# Step: 2900            	|	 Train loss: 1.180      	|	 Test loss: 2.159
# Step: 2950            	|	 Train loss: 1.177      	|	 Test loss: 2.163
# Step: 3000            	|	 Train loss: 1.172      	|	 Test loss: 2.169
# Step: 3050            	|	 Train loss: 1.161      	|	 Test loss: 2.179
# Step: 3100            	|	 Train loss: 1.147      	|	 Test loss: 2.189
# Step: 3150            	|	 Train loss: 1.145      	|	 Test loss: 2.188
# Step: 3200            	|	 Train loss: 1.144      	|	 Test loss: 2.187
# Step: 3250            	|	 Train loss: 1.143      	|	 Test loss: 2.186
# Step: 3300            	|	 Train loss: 1.142      	|	 Test loss: 2.185
# Step: 3350            	|	 Train loss: 1.141      	|	 Test loss: 2.184
# Step: 3400            	|	 Train loss: 1.140      	|	 Test loss: 2.184
# Step: 3450            	|	 Train loss: 1.140      	|	 Test loss: 2.184
# Step: 3500            	|	 Train loss: 1.139      	|	 Test loss: 2.183
# Step: 3550            	|	 Train loss: 1.139      	|	 Test loss: 2.183
# Step: 3600            	|	 Train loss: 1.139      	|	 Test loss: 2.183
# Step: 3650            	|	 Train loss: 1.138      	|	 Test loss: 2.183
# Step: 3700            	|	 Train loss: 1.138      	|	 Test loss: 2.183
# Step: 3750            	|	 Train loss: 1.138      	|	 Test loss: 2.183
# Step: 3800            	|	 Train loss: 1.138      	|	 Test loss: 2.184
# Step: 3850            	|	 Train loss: 1.137      	|	 Test loss: 2.184
# Step: 3900            	|	 Train loss: 1.137      	|	 Test loss: 2.185
# Step: 3950            	|	 Train loss: 1.137      	|	 Test loss: 2.185
# Step: 4000            	|	 Train loss: 1.137      	|	 Test loss: 2.186
# Step: 4050            	|	 Train loss: 1.137      	|	 Test loss: 2.187
# Step: 4100            	|	 Train loss: 1.136      	|	 Test loss: 2.188
# Step: 4150            	|	 Train loss: 1.136      	|	 Test loss: 2.188
# Step: 4200            	|	 Train loss: 1.136      	|	 Test loss: 2.189
# Step: 4250            	|	 Train loss: 1.136      	|	 Test loss: 2.190
# Step: 4300            	|	 Train loss: 1.136      	|	 Test loss: 2.191
# Step: 4350            	|	 Train loss: 1.136      	|	 Test loss: 2.192
# Step: 4400            	|	 Train loss: 1.135      	|	 Test loss: 2.194
# Step: 4450            	|	 Train loss: 1.134      	|	 Test loss: 2.196
# Step: 4500            	|	 Train loss: 1.134      	|	 Test loss: 2.198
# Step: 4550            	|	 Train loss: 1.133      	|	 Test loss: 2.199
# Step: 4600            	|	 Train loss: 1.133      	|	 Test loss: 2.201
# Step: 4650            	|	 Train loss: 1.133      	|	 Test loss: 2.202
# Step: 4700            	|	 Train loss: 1.132      	|	 Test loss: 2.203
# Step: 4750            	|	 Train loss: 1.132      	|	 Test loss: 2.204
# Step: 4800            	|	 Train loss: 1.132      	|	 Test loss: 2.205
# Step: 4850            	|	 Train loss: 1.132      	|	 Test loss: 2.205
# Step: 4900            	|	 Train loss: 1.132      	|	 Test loss: 2.206
# Step: 4950            	|	 Train loss: 1.131      	|	 Test loss: 2.207
# Step: 5000            	|	 Train loss: 1.131      	|	 Test loss: 2.207
# Step: 5050            	|	 Train loss: 1.131      	|	 Test loss: 2.208
# Step: 5100            	|	 Train loss: 1.131      	|	 Test loss: 2.208
# Step: 5150            	|	 Train loss: 1.131      	|	 Test loss: 2.209
# Step: 5200            	|	 Train loss: 1.131      	|	 Test loss: 2.210
# Step: 5250            	|	 Train loss: 1.131      	|	 Test loss: 2.210
# Step: 5300            	|	 Train loss: 1.131      	|	 Test loss: 2.210
# Step: 5350            	|	 Train loss: 1.131      	|	 Test loss: 2.211
# Step: 5400            	|	 Train loss: 1.131      	|	 Test loss: 2.211
# Step: 5450            	|	 Train loss: 1.130      	|	 Test loss: 2.212
# Step: 5500            	|	 Train loss: 1.130      	|	 Test loss: 2.212
# Step: 5550            	|	 Train loss: 1.130      	|	 Test loss: 2.212
# Step: 5600            	|	 Train loss: 1.130      	|	 Test loss: 2.213
# Step: 5650            	|	 Train loss: 1.130      	|	 Test loss: 2.213
# Step: 5700            	|	 Train loss: 1.130      	|	 Test loss: 2.213
# Step: 5750            	|	 Train loss: 1.130      	|	 Test loss: 2.214
# Step: 5800            	|	 Train loss: 1.130      	|	 Test loss: 2.214
# Step: 5850            	|	 Train loss: 1.130      	|	 Test loss: 2.214
# Step: 5900            	|	 Train loss: 1.130      	|	 Test loss: 2.215
# Step: 5950            	|	 Train loss: 1.130      	|	 Test loss: 2.215
# Step: 6000            	|	 Train loss: 1.130      	|	 Test loss: 2.215
# Step: 6050            	|	 Train loss: 1.130      	|	 Test loss: 2.216
# Step: 6100            	|	 Train loss: 1.130      	|	 Test loss: 2.216
# Step: 6150            	|	 Train loss: 1.130      	|	 Test loss: 2.216
# Step: 6200            	|	 Train loss: 1.130      	|	 Test loss: 2.216
# Step: 6250            	|	 Train loss: 1.130      	|	 Test loss: 2.217
# Step: 6300            	|	 Train loss: 1.130      	|	 Test loss: 2.217
# Step: 6350            	|	 Train loss: 1.130      	|	 Test loss: 2.217
# Step: 6400            	|	 Train loss: 1.130      	|	 Test loss: 2.217
# Step: 6450            	|	 Train loss: 1.130      	|	 Test loss: 2.218
# Step: 6500            	|	 Train loss: 1.130      	|	 Test loss: 2.218
# Step: 6550            	|	 Train loss: 1.130      	|	 Test loss: 2.218
# Step: 6600            	|	 Train loss: 1.130      	|	 Test loss: 2.218
# Step: 6650            	|	 Train loss: 1.130      	|	 Test loss: 2.219
# Step: 6700            	|	 Train loss: 1.130      	|	 Test loss: 2.219
# Step: 6750            	|	 Train loss: 1.130      	|	 Test loss: 2.219
# Step: 6800            	|	 Train loss: 1.130      	|	 Test loss: 2.219
# Step: 6850            	|	 Train loss: 1.130      	|	 Test loss: 2.219
# Step: 6900            	|	 Train loss: 1.129      	|	 Test loss: 2.220
# Step: 6950            	|	 Train loss: 1.129      	|	 Test loss: 2.220
# Step: 7000            	|	 Train loss: 1.129      	|	 Test loss: 2.220
# Step: 7050            	|	 Train loss: 1.129      	|	 Test loss: 2.220
# Step: 7100            	|	 Train loss: 1.129      	|	 Test loss: 2.220
# Step: 7150            	|	 Train loss: 1.129      	|	 Test loss: 2.221
# Step: 7200            	|	 Train loss: 1.129      	|	 Test loss: 2.221
# Step: 7250            	|	 Train loss: 1.129      	|	 Test loss: 2.221
# Step: 7300            	|	 Train loss: 1.129      	|	 Test loss: 2.221
# Step: 7350            	|	 Train loss: 1.129      	|	 Test loss: 2.221
# Step: 7400            	|	 Train loss: 1.129      	|	 Test loss: 2.221
# Step: 7450            	|	 Train loss: 1.129      	|	 Test loss: 2.222
# Step: 7500            	|	 Train loss: 1.129      	|	 Test loss: 2.222
# Step: 7550            	|	 Train loss: 1.129      	|	 Test loss: 2.222
# Step: 7600            	|	 Train loss: 1.129      	|	 Test loss: 2.222
# Step: 7650            	|	 Train loss: 1.129      	|	 Test loss: 2.222
# Step: 7700            	|	 Train loss: 1.129      	|	 Test loss: 2.222
# Step: 7750            	|	 Train loss: 1.129      	|	 Test loss: 2.223
# Step: 7800            	|	 Train loss: 1.129      	|	 Test loss: 2.223
# Step: 7850            	|	 Train loss: 1.129      	|	 Test loss: 2.223
# Step: 7900            	|	 Train loss: 1.129      	|	 Test loss: 2.223
# Step: 7950            	|	 Train loss: 1.129      	|	 Test loss: 2.223
# Step: 8000            	|	 Train loss: 1.129      	|	 Test loss: 2.223
# Step: 8050            	|	 Train loss: 1.129      	|	 Test loss: 2.223
# Step: 8100            	|	 Train loss: 1.129      	|	 Test loss: 2.224
# Step: 8150            	|	 Train loss: 1.129      	|	 Test loss: 2.224
# Step: 8200            	|	 Train loss: 1.129      	|	 Test loss: 2.224
# Step: 8250            	|	 Train loss: 1.129      	|	 Test loss: 2.224
# Step: 8300            	|	 Train loss: 1.129      	|	 Test loss: 2.224
# Step: 8350            	|	 Train loss: 1.129      	|	 Test loss: 2.224
# Step: 8400            	|	 Train loss: 1.129      	|	 Test loss: 2.224
# Step: 8450            	|	 Train loss: 1.129      	|	 Test loss: 2.224
# Step: 8500            	|	 Train loss: 1.129      	|	 Test loss: 2.225
# Step: 8550            	|	 Train loss: 1.129      	|	 Test loss: 2.225
# Step: 8600            	|	 Train loss: 1.129      	|	 Test loss: 2.225
# Step: 8650            	|	 Train loss: 1.129      	|	 Test loss: 2.225
# Step: 8700            	|	 Train loss: 1.129      	|	 Test loss: 2.225
# Step: 8750            	|	 Train loss: 1.129      	|	 Test loss: 2.225
# Step: 8800            	|	 Train loss: 1.129      	|	 Test loss: 2.225
# Step: 8850            	|	 Train loss: 1.129      	|	 Test loss: 2.225
# Step: 8900            	|	 Train loss: 1.129      	|	 Test loss: 2.225
# Step: 8950            	|	 Train loss: 1.129      	|	 Test loss: 2.226
# Step: 9000            	|	 Train loss: 1.129      	|	 Test loss: 2.226
# Step: 9050            	|	 Train loss: 1.129      	|	 Test loss: 2.226
# Step: 9100            	|	 Train loss: 1.129      	|	 Test loss: 2.226
# Step: 9150            	|	 Train loss: 1.129      	|	 Test loss: 2.226
# Step: 9200            	|	 Train loss: 1.129      	|	 Test loss: 2.226
# Step: 9250            	|	 Train loss: 1.129      	|	 Test loss: 2.226
# Step: 9300            	|	 Train loss: 1.129      	|	 Test loss: 2.226
# Step: 9350            	|	 Train loss: 1.129      	|	 Test loss: 2.226
# Step: 9400            	|	 Train loss: 1.129      	|	 Test loss: 2.226
# Step: 9450            	|	 Train loss: 1.129      	|	 Test loss: 2.226
# Step: 9500            	|	 Train loss: 1.129      	|	 Test loss: 2.226
# Step: 9550            	|	 Train loss: 1.129      	|	 Test loss: 2.226
# Step: 9600            	|	 Train loss: 1.129      	|	 Test loss: 2.226
# Step: 9650            	|	 Train loss: 1.129      	|	 Test loss: 2.226
# Step: 9700            	|	 Train loss: 1.129      	|	 Test loss: 2.227
# Step: 9750            	|	 Train loss: 1.129      	|	 Test loss: 2.227
# Step: 9800            	|	 Train loss: 1.129      	|	 Test loss: 2.227
# Step: 9850            	|	 Train loss: 1.128      	|	 Test loss: 2.227
# Step: 9900            	|	 Train loss: 1.128      	|	 Test loss: 2.227
# Step: 9950            	|	 Train loss: 1.128      	|	 Test loss: 2.227
# Step: 10000           	|	 Train loss: 1.128      	|	 Test loss: 2.227
# Step: 10050           	|	 Train loss: 1.128      	|	 Test loss: 2.227
# Step: 10100           	|	 Train loss: 1.128      	|	 Test loss: 2.227
# Step: 10150           	|	 Train loss: 1.128      	|	 Test loss: 2.227
# Step: 10200           	|	 Train loss: 1.128      	|	 Test loss: 2.227
# Step: 10250           	|	 Train loss: 1.128      	|	 Test loss: 2.227
# Step: 10300           	|	 Train loss: 1.128      	|	 Test loss: 2.227
# Step: 10350           	|	 Train loss: 1.128      	|	 Test loss: 2.227
# Step: 10400           	|	 Train loss: 1.128      	|	 Test loss: 2.227
# Step: 10450           	|	 Train loss: 1.128      	|	 Test loss: 2.227
# Step: 10500           	|	 Train loss: 1.128      	|	 Test loss: 2.227
# Step: 10550           	|	 Train loss: 1.128      	|	 Test loss: 2.227
# Step: 10600           	|	 Train loss: 1.128      	|	 Test loss: 2.227
# Step: 10650           	|	 Train loss: 1.128      	|	 Test loss: 2.227
# Step: 10700           	|	 Train loss: 1.128      	|	 Test loss: 2.227
# Step: 10750           	|	 Train loss: 1.128      	|	 Test loss: 2.227
# Step: 10800           	|	 Train loss: 1.128      	|	 Test loss: 2.227
# Step: 10850           	|	 Train loss: 1.128      	|	 Test loss: 2.227
# Step: 10900           	|	 Train loss: 1.128      	|	 Test loss: 2.227
# Step: 10950           	|	 Train loss: 1.128      	|	 Test loss: 2.227
# Step: 11000           	|	 Train loss: 1.128      	|	 Test loss: 2.227
# Step: 11050           	|	 Train loss: 1.128      	|	 Test loss: 2.227
# Step: 11100           	|	 Train loss: 1.128      	|	 Test loss: 2.227
# Step: 11150           	|	 Train loss: 1.128      	|	 Test loss: 2.227
# Step: 11200           	|	 Train loss: 1.128      	|	 Test loss: 2.227
# Step: 11250           	|	 Train loss: 1.128      	|	 Test loss: 2.227
# Step: 11300           	|	 Train loss: 1.128      	|	 Test loss: 2.227
# Step: 11350           	|	 Train loss: 1.128      	|	 Test loss: 2.227
# Step: 11400           	|	 Train loss: 1.128      	|	 Test loss: 2.228
# Step: 11450           	|	 Train loss: 1.128      	|	 Test loss: 2.228
# Step: 11500           	|	 Train loss: 1.128      	|	 Test loss: 2.228
# Step: 11550           	|	 Train loss: 1.128      	|	 Test loss: 2.228
# Step: 11600           	|	 Train loss: 1.128      	|	 Test loss: 2.228
# Step: 11650           	|	 Train loss: 1.128      	|	 Test loss: 2.228
# Step: 11700           	|	 Train loss: 1.128      	|	 Test loss: 2.228
# Step: 11750           	|	 Train loss: 1.128      	|	 Test loss: 2.228
# Step: 11800           	|	 Train loss: 1.128      	|	 Test loss: 2.229
# Step: 11850           	|	 Train loss: 1.128      	|	 Test loss: 2.229
# Step: 11900           	|	 Train loss: 1.128      	|	 Test loss: 2.229
# Step: 11950           	|	 Train loss: 1.128      	|	 Test loss: 2.229
# Step: 12000           	|	 Train loss: 1.128      	|	 Test loss: 2.229
# Step: 12050           	|	 Train loss: 1.128      	|	 Test loss: 2.230
# Step: 12100           	|	 Train loss: 1.128      	|	 Test loss: 2.230
# Step: 12150           	|	 Train loss: 1.128      	|	 Test loss: 2.230
# Step: 12200           	|	 Train loss: 1.128      	|	 Test loss: 2.230
# Step: 12250           	|	 Train loss: 1.128      	|	 Test loss: 2.230
# Step: 12300           	|	 Train loss: 1.128      	|	 Test loss: 2.231
# Step: 12350           	|	 Train loss: 1.128      	|	 Test loss: 2.231
# Step: 12400           	|	 Train loss: 1.128      	|	 Test loss: 2.231
# Step: 12450           	|	 Train loss: 1.128      	|	 Test loss: 2.231
# Step: 12500           	|	 Train loss: 1.127      	|	 Test loss: 2.231
# Step: 12550           	|	 Train loss: 1.127      	|	 Test loss: 2.232
# Step: 12600           	|	 Train loss: 1.127      	|	 Test loss: 2.232
# Step: 12650           	|	 Train loss: 1.127      	|	 Test loss: 2.232
# Step: 12700           	|	 Train loss: 1.127      	|	 Test loss: 2.232
# Step: 12750           	|	 Train loss: 1.127      	|	 Test loss: 2.233
# Step: 12800           	|	 Train loss: 1.127      	|	 Test loss: 2.233
# Step: 12850           	|	 Train loss: 1.127      	|	 Test loss: 2.233
# Step: 12900           	|	 Train loss: 1.127      	|	 Test loss: 2.233
# Step: 12950           	|	 Train loss: 1.127      	|	 Test loss: 2.233
# Step: 13000           	|	 Train loss: 1.127      	|	 Test loss: 2.233
# Step: 13050           	|	 Train loss: 1.127      	|	 Test loss: 2.234
# Step: 13100           	|	 Train loss: 1.127      	|	 Test loss: 2.234
# Step: 13150           	|	 Train loss: 1.127      	|	 Test loss: 2.234
# Step: 13200           	|	 Train loss: 1.127      	|	 Test loss: 2.234
# Step: 13250           	|	 Train loss: 1.127      	|	 Test loss: 2.234
# Step: 13300           	|	 Train loss: 1.127      	|	 Test loss: 2.235
# Step: 13350           	|	 Train loss: 1.127      	|	 Test loss: 2.235
# Step: 13400           	|	 Train loss: 1.127      	|	 Test loss: 2.235
# Step: 13450           	|	 Train loss: 1.127      	|	 Test loss: 2.235
# Step: 13500           	|	 Train loss: 1.127      	|	 Test loss: 2.235
# Step: 13550           	|	 Train loss: 1.127      	|	 Test loss: 2.235
# Step: 13600           	|	 Train loss: 1.127      	|	 Test loss: 2.236
# Step: 13650           	|	 Train loss: 1.127      	|	 Test loss: 2.236
# Step: 13700           	|	 Train loss: 1.127      	|	 Test loss: 2.236
# Step: 13750           	|	 Train loss: 1.127      	|	 Test loss: 2.236
# Step: 13800           	|	 Train loss: 1.126      	|	 Test loss: 2.236
# Step: 13850           	|	 Train loss: 1.126      	|	 Test loss: 2.236
# Step: 13900           	|	 Train loss: 1.126      	|	 Test loss: 2.236
# Step: 13950           	|	 Train loss: 1.126      	|	 Test loss: 2.237
# Step: 14000           	|	 Train loss: 1.126      	|	 Test loss: 2.237
# Step: 14050           	|	 Train loss: 1.126      	|	 Test loss: 2.237
# Step: 14100           	|	 Train loss: 1.126      	|	 Test loss: 2.237
# Step: 14150           	|	 Train loss: 1.126      	|	 Test loss: 2.237
# Step: 14200           	|	 Train loss: 1.126      	|	 Test loss: 2.237
# Step: 14250           	|	 Train loss: 1.126      	|	 Test loss: 2.237
# Step: 14300           	|	 Train loss: 1.125      	|	 Test loss: 2.238
# Step: 14350           	|	 Train loss: 1.125      	|	 Test loss: 2.238
# Step: 14400           	|	 Train loss: 1.125      	|	 Test loss: 2.238
# Step: 14450           	|	 Train loss: 1.125      	|	 Test loss: 2.238
# Step: 14500           	|	 Train loss: 1.124      	|	 Test loss: 2.238
# Step: 14550           	|	 Train loss: 1.124      	|	 Test loss: 2.239
# Step: 14600           	|	 Train loss: 1.123      	|	 Test loss: 2.239
# Step: 14650           	|	 Train loss: 1.123      	|	 Test loss: 2.239
# Step: 14700           	|	 Train loss: 1.123      	|	 Test loss: 2.240
# Step: 14750           	|	 Train loss: 1.123      	|	 Test loss: 2.240
# Step: 14800           	|	 Train loss: 1.123      	|	 Test loss: 2.241
# Step: 14850           	|	 Train loss: 1.122      	|	 Test loss: 2.241
# Step: 14900           	|	 Train loss: 1.122      	|	 Test loss: 2.241
# Step: 14950           	|	 Train loss: 1.122      	|	 Test loss: 2.242
# Step: 15000           	|	 Train loss: 1.122      	|	 Test loss: 2.242
# Step: 15050           	|	 Train loss: 1.122      	|	 Test loss: 2.243
# Step: 15100           	|	 Train loss: 1.122      	|	 Test loss: 2.243
# Step: 15150           	|	 Train loss: 1.122      	|	 Test loss: 2.243
# Step: 15200           	|	 Train loss: 1.122      	|	 Test loss: 2.243
# Step: 15250           	|	 Train loss: 1.122      	|	 Test loss: 2.244
# Step: 15300           	|	 Train loss: 1.122      	|	 Test loss: 2.244
# Step: 15350           	|	 Train loss: 1.122      	|	 Test loss: 2.244
# Step: 15400           	|	 Train loss: 1.122      	|	 Test loss: 2.244
# Step: 15450           	|	 Train loss: 1.122      	|	 Test loss: 2.244
# Step: 15500           	|	 Train loss: 1.122      	|	 Test loss: 2.245
# Step: 15550           	|	 Train loss: 1.122      	|	 Test loss: 2.245
# Step: 15600           	|	 Train loss: 1.122      	|	 Test loss: 2.245
# Step: 15650           	|	 Train loss: 1.122      	|	 Test loss: 2.245
# Step: 15700           	|	 Train loss: 1.122      	|	 Test loss: 2.245
# Step: 15750           	|	 Train loss: 1.122      	|	 Test loss: 2.245
# Step: 15800           	|	 Train loss: 1.122      	|	 Test loss: 2.245
# Step: 15850           	|	 Train loss: 1.122      	|	 Test loss: 2.245
# Step: 15900           	|	 Train loss: 1.122      	|	 Test loss: 2.246
# Step: 15950           	|	 Train loss: 1.122      	|	 Test loss: 2.246
# Step: 16000           	|	 Train loss: 1.122      	|	 Test loss: 2.246
# Step: 16050           	|	 Train loss: 1.122      	|	 Test loss: 2.246
# Step: 16100           	|	 Train loss: 1.122      	|	 Test loss: 2.246
# Step: 16150           	|	 Train loss: 1.122      	|	 Test loss: 2.246
# Step: 16200           	|	 Train loss: 1.122      	|	 Test loss: 2.246
# Step: 16250           	|	 Train loss: 1.122      	|	 Test loss: 2.246
# Step: 16300           	|	 Train loss: 1.122      	|	 Test loss: 2.246
# Step: 16350           	|	 Train loss: 1.122      	|	 Test loss: 2.246
# Step: 16400           	|	 Train loss: 1.122      	|	 Test loss: 2.246
# Step: 16450           	|	 Train loss: 1.122      	|	 Test loss: 2.246
# Step: 16500           	|	 Train loss: 1.122      	|	 Test loss: 2.246
# Step: 16550           	|	 Train loss: 1.122      	|	 Test loss: 2.246
# Step: 16600           	|	 Train loss: 1.122      	|	 Test loss: 2.246
# Step: 16650           	|	 Train loss: 1.122      	|	 Test loss: 2.246
# Step: 16700           	|	 Train loss: 1.122      	|	 Test loss: 2.246
# Step: 16750           	|	 Train loss: 1.122      	|	 Test loss: 2.246
# Step: 16800           	|	 Train loss: 1.122      	|	 Test loss: 2.246
# Step: 16850           	|	 Train loss: 1.122      	|	 Test loss: 2.246
# Step: 16900           	|	 Train loss: 1.122      	|	 Test loss: 2.246
# Step: 16950           	|	 Train loss: 1.122      	|	 Test loss: 2.246
# Step: 17000           	|	 Train loss: 1.122      	|	 Test loss: 2.246
# Step: 17050           	|	 Train loss: 1.122      	|	 Test loss: 2.246
# Step: 17100           	|	 Train loss: 1.122      	|	 Test loss: 2.246
# Step: 17150           	|	 Train loss: 1.122      	|	 Test loss: 2.246
# Step: 17200           	|	 Train loss: 1.122      	|	 Test loss: 2.246
# Step: 17250           	|	 Train loss: 1.122      	|	 Test loss: 2.246
# Step: 17300           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 17350           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 17400           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 17450           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 17500           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 17550           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 17600           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 17650           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 17700           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 17750           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 17800           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 17850           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 17900           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 17950           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 18000           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 18050           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 18100           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 18150           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 18200           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 18250           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 18300           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 18350           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 18400           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 18450           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 18500           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 18550           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 18600           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 18650           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 18700           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 18750           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 18800           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 18850           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 18900           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 18950           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 19000           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 19050           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 19100           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 19150           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 19200           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 19250           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 19300           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 19350           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 19400           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 19450           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 19500           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 19550           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 19600           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 19650           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 19700           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 19750           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 19800           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 19850           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 19900           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 19950           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 20000           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 20050           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 20100           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 20150           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 20200           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 20250           	|	 Train loss: 1.122      	|	 Test loss: 2.247
# Step: 20300           	|	 Train loss: 1.122      	|	 Test loss: 2.248
# Step: 20350           	|	 Train loss: 1.122      	|	 Test loss: 2.248
# Step: 20400           	|	 Train loss: 1.122      	|	 Test loss: 2.248
# Step: 20450           	|	 Train loss: 1.122      	|	 Test loss: 2.248
# Step: 20500           	|	 Train loss: 1.122      	|	 Test loss: 2.248
# Step: 20550           	|	 Train loss: 1.122      	|	 Test loss: 2.248
# Step: 20600           	|	 Train loss: 1.122      	|	 Test loss: 2.248
# Step: 20650           	|	 Train loss: 1.122      	|	 Test loss: 2.248
# Step: 20700           	|	 Train loss: 1.122      	|	 Test loss: 2.248
# Step: 20750           	|	 Train loss: 1.122      	|	 Test loss: 2.248
# Step: 20800           	|	 Train loss: 1.122      	|	 Test loss: 2.248
# Step: 20850           	|	 Train loss: 1.122      	|	 Test loss: 2.248
# Step: 20900           	|	 Train loss: 1.122      	|	 Test loss: 2.248
# Step: 20950           	|	 Train loss: 1.122      	|	 Test loss: 2.248
# Step: 21000           	|	 Train loss: 1.122      	|	 Test loss: 2.248
# Step: 21050           	|	 Train loss: 1.122      	|	 Test loss: 2.248
# Step: 21100           	|	 Train loss: 1.122      	|	 Test loss: 2.248
# Step: 21150           	|	 Train loss: 1.122      	|	 Test loss: 2.248
# Step: 21200           	|	 Train loss: 1.122      	|	 Test loss: 2.248
# Step: 21250           	|	 Train loss: 1.122      	|	 Test loss: 2.249
# Step: 21300           	|	 Train loss: 1.122      	|	 Test loss: 2.249
# Step: 21350           	|	 Train loss: 1.122      	|	 Test loss: 2.249
# Step: 21400           	|	 Train loss: 1.122      	|	 Test loss: 2.249
# Step: 21450           	|	 Train loss: 1.122      	|	 Test loss: 2.249
# Step: 21500           	|	 Train loss: 1.122      	|	 Test loss: 2.249
# Step: 21550           	|	 Train loss: 1.122      	|	 Test loss: 2.249
# Step: 21600           	|	 Train loss: 1.122      	|	 Test loss: 2.249
# Step: 21650           	|	 Train loss: 1.122      	|	 Test loss: 2.249
# Step: 21700           	|	 Train loss: 1.122      	|	 Test loss: 2.250
# Step: 21750           	|	 Train loss: 1.122      	|	 Test loss: 2.250
# Step: 21800           	|	 Train loss: 1.122      	|	 Test loss: 2.250
# Step: 21850           	|	 Train loss: 1.122      	|	 Test loss: 2.250
# Step: 21900           	|	 Train loss: 1.122      	|	 Test loss: 2.250
# Step: 21950           	|	 Train loss: 1.122      	|	 Test loss: 2.250
# Step: 22000           	|	 Train loss: 1.122      	|	 Test loss: 2.251
# Step: 22050           	|	 Train loss: 1.122      	|	 Test loss: 2.251
# Step: 22100           	|	 Train loss: 1.122      	|	 Test loss: 2.251
# Step: 22150           	|	 Train loss: 1.122      	|	 Test loss: 2.251
# Step: 22200           	|	 Train loss: 1.122      	|	 Test loss: 2.251
# Step: 22250           	|	 Train loss: 1.122      	|	 Test loss: 2.252
# Step: 22300           	|	 Train loss: 1.122      	|	 Test loss: 2.252
# Step: 22350           	|	 Train loss: 1.121      	|	 Test loss: 2.252
# Step: 22400           	|	 Train loss: 1.121      	|	 Test loss: 2.253
# Step: 22450           	|	 Train loss: 1.121      	|	 Test loss: 2.253
# Step: 22500           	|	 Train loss: 1.121      	|	 Test loss: 2.253
# Step: 22550           	|	 Train loss: 1.121      	|	 Test loss: 2.253
# Step: 22600           	|	 Train loss: 1.121      	|	 Test loss: 2.254
# Step: 22650           	|	 Train loss: 1.121      	|	 Test loss: 2.254
# Step: 22700           	|	 Train loss: 1.121      	|	 Test loss: 2.254
# Step: 22750           	|	 Train loss: 1.121      	|	 Test loss: 2.255
# Step: 22800           	|	 Train loss: 1.121      	|	 Test loss: 2.255
# Step: 22850           	|	 Train loss: 1.121      	|	 Test loss: 2.255
# Step: 22900           	|	 Train loss: 1.121      	|	 Test loss: 2.256
# Step: 22950           	|	 Train loss: 1.121      	|	 Test loss: 2.256
# Step: 23000           	|	 Train loss: 1.121      	|	 Test loss: 2.256
# Step: 23050           	|	 Train loss: 1.121      	|	 Test loss: 2.257
# Step: 23100           	|	 Train loss: 1.121      	|	 Test loss: 2.257
# Step: 23150           	|	 Train loss: 1.121      	|	 Test loss: 2.257
# Step: 23200           	|	 Train loss: 1.121      	|	 Test loss: 2.258
# Step: 23250           	|	 Train loss: 1.121      	|	 Test loss: 2.258
# Step: 23300           	|	 Train loss: 1.121      	|	 Test loss: 2.258
# Step: 23350           	|	 Train loss: 1.121      	|	 Test loss: 2.258
# Step: 23400           	|	 Train loss: 1.121      	|	 Test loss: 2.259
# Step: 23450           	|	 Train loss: 1.120      	|	 Test loss: 2.259
# Step: 23500           	|	 Train loss: 1.120      	|	 Test loss: 2.259
# Step: 23550           	|	 Train loss: 1.120      	|	 Test loss: 2.259
# Step: 23600           	|	 Train loss: 1.120      	|	 Test loss: 2.260
# Step: 23650           	|	 Train loss: 1.120      	|	 Test loss: 2.260
# Step: 23700           	|	 Train loss: 1.120      	|	 Test loss: 2.260
# Step: 23750           	|	 Train loss: 1.120      	|	 Test loss: 2.260
# Step: 23800           	|	 Train loss: 1.120      	|	 Test loss: 2.261
# Step: 23850           	|	 Train loss: 1.120      	|	 Test loss: 2.261
# Step: 23900           	|	 Train loss: 1.120      	|	 Test loss: 2.261
# Step: 23950           	|	 Train loss: 1.120      	|	 Test loss: 2.262
# Step: 24000           	|	 Train loss: 1.120      	|	 Test loss: 2.262
# Step: 24050           	|	 Train loss: 1.120      	|	 Test loss: 2.262
# Step: 24100           	|	 Train loss: 1.120      	|	 Test loss: 2.262
# Step: 24150           	|	 Train loss: 1.120      	|	 Test loss: 2.263
# Step: 24200           	|	 Train loss: 1.119      	|	 Test loss: 2.263
# Step: 24250           	|	 Train loss: 1.119      	|	 Test loss: 2.264
# Step: 24300           	|	 Train loss: 1.119      	|	 Test loss: 2.264
# Step: 24350           	|	 Train loss: 1.119      	|	 Test loss: 2.264
# Step: 24400           	|	 Train loss: 1.119      	|	 Test loss: 2.265
# Step: 24450           	|	 Train loss: 1.119      	|	 Test loss: 2.265
# Step: 24500           	|	 Train loss: 1.119      	|	 Test loss: 2.265
# Step: 24550           	|	 Train loss: 1.119      	|	 Test loss: 2.266
# Step: 24600           	|	 Train loss: 1.119      	|	 Test loss: 2.266
# Step: 24650           	|	 Train loss: 1.119      	|	 Test loss: 2.267
# Step: 24700           	|	 Train loss: 1.119      	|	 Test loss: 2.267
# Step: 24750           	|	 Train loss: 1.119      	|	 Test loss: 2.268
# Step: 24800           	|	 Train loss: 1.119      	|	 Test loss: 2.268
# Step: 24850           	|	 Train loss: 1.119      	|	 Test loss: 2.268
# Step: 24900           	|	 Train loss: 1.119      	|	 Test loss: 2.269
# Step: 24950           	|	 Train loss: 1.119      	|	 Test loss: 2.269
# Step: 25000           	|	 Train loss: 1.118      	|	 Test loss: 2.270
# Step: 25050           	|	 Train loss: 1.118      	|	 Test loss: 2.270
# Step: 25100           	|	 Train loss: 1.118      	|	 Test loss: 2.270
# Step: 25150           	|	 Train loss: 1.118      	|	 Test loss: 2.271
# Step: 25200           	|	 Train loss: 1.118      	|	 Test loss: 2.271
# Step: 25250           	|	 Train loss: 1.118      	|	 Test loss: 2.271
# Step: 25300           	|	 Train loss: 1.118      	|	 Test loss: 2.272
# Step: 25350           	|	 Train loss: 1.118      	|	 Test loss: 2.272
# Step: 25400           	|	 Train loss: 1.118      	|	 Test loss: 2.272
# Step: 25450           	|	 Train loss: 1.118      	|	 Test loss: 2.273
# Step: 25500           	|	 Train loss: 1.118      	|	 Test loss: 2.273
# Step: 25550           	|	 Train loss: 1.118      	|	 Test loss: 2.273
# Step: 25600           	|	 Train loss: 1.118      	|	 Test loss: 2.274
# Step: 25650           	|	 Train loss: 1.118      	|	 Test loss: 2.274
# Step: 25700           	|	 Train loss: 1.118      	|	 Test loss: 2.274
# Step: 25750           	|	 Train loss: 1.118      	|	 Test loss: 2.275
# Step: 25800           	|	 Train loss: 1.118      	|	 Test loss: 2.275
# Step: 25850           	|	 Train loss: 1.118      	|	 Test loss: 2.275
# Step: 25900           	|	 Train loss: 1.118      	|	 Test loss: 2.276
# Step: 25950           	|	 Train loss: 1.118      	|	 Test loss: 2.276
# Step: 26000           	|	 Train loss: 1.118      	|	 Test loss: 2.276
# Step: 26050           	|	 Train loss: 1.118      	|	 Test loss: 2.276
# Step: 26100           	|	 Train loss: 1.118      	|	 Test loss: 2.277
# Step: 26150           	|	 Train loss: 1.117      	|	 Test loss: 2.277
# Step: 26200           	|	 Train loss: 1.117      	|	 Test loss: 2.277
# Step: 26250           	|	 Train loss: 1.117      	|	 Test loss: 2.278
# Step: 26300           	|	 Train loss: 1.117      	|	 Test loss: 2.278
# Step: 26350           	|	 Train loss: 1.117      	|	 Test loss: 2.278
# Step: 26400           	|	 Train loss: 1.117      	|	 Test loss: 2.278
# Step: 26450           	|	 Train loss: 1.117      	|	 Test loss: 2.279
# Step: 26500           	|	 Train loss: 1.117      	|	 Test loss: 2.279
# Step: 26550           	|	 Train loss: 1.117      	|	 Test loss: 2.279
# Step: 26600           	|	 Train loss: 1.117      	|	 Test loss: 2.279
# Step: 26650           	|	 Train loss: 1.117      	|	 Test loss: 2.279
# Step: 26700           	|	 Train loss: 1.117      	|	 Test loss: 2.280
# Step: 26750           	|	 Train loss: 1.117      	|	 Test loss: 2.280
# Step: 26800           	|	 Train loss: 1.117      	|	 Test loss: 2.280
# Step: 26850           	|	 Train loss: 1.117      	|	 Test loss: 2.280
# Step: 26900           	|	 Train loss: 1.117      	|	 Test loss: 2.281
# Step: 26950           	|	 Train loss: 1.117      	|	 Test loss: 2.281
# Step: 27000           	|	 Train loss: 1.117      	|	 Test loss: 2.281
# Step: 27050           	|	 Train loss: 1.117      	|	 Test loss: 2.281
# Step: 27100           	|	 Train loss: 1.117      	|	 Test loss: 2.281
# Step: 27150           	|	 Train loss: 1.117      	|	 Test loss: 2.281
# Step: 27200           	|	 Train loss: 1.117      	|	 Test loss: 2.282
# Step: 27250           	|	 Train loss: 1.117      	|	 Test loss: 2.282
# Step: 27300           	|	 Train loss: 1.117      	|	 Test loss: 2.282
# Step: 27350           	|	 Train loss: 1.117      	|	 Test loss: 2.282
# Step: 27400           	|	 Train loss: 1.117      	|	 Test loss: 2.282
# Step: 27450           	|	 Train loss: 1.117      	|	 Test loss: 2.283
# Step: 27500           	|	 Train loss: 1.117      	|	 Test loss: 2.283
# Step: 27550           	|	 Train loss: 1.117      	|	 Test loss: 2.283
# Step: 27600           	|	 Train loss: 1.117      	|	 Test loss: 2.283
# Step: 27650           	|	 Train loss: 1.117      	|	 Test loss: 2.283
# Step: 27700           	|	 Train loss: 1.117      	|	 Test loss: 2.283
# Step: 27750           	|	 Train loss: 1.117      	|	 Test loss: 2.284
# Step: 27800           	|	 Train loss: 1.117      	|	 Test loss: 2.284
# Step: 27850           	|	 Train loss: 1.117      	|	 Test loss: 2.284
# Step: 27900           	|	 Train loss: 1.117      	|	 Test loss: 2.284
# Step: 27950           	|	 Train loss: 1.117      	|	 Test loss: 2.284
# Step: 28000           	|	 Train loss: 1.117      	|	 Test loss: 2.284
# Step: 28050           	|	 Train loss: 1.117      	|	 Test loss: 2.284
# Step: 28100           	|	 Train loss: 1.117      	|	 Test loss: 2.284
# Step: 28150           	|	 Train loss: 1.117      	|	 Test loss: 2.285
# Step: 28200           	|	 Train loss: 1.117      	|	 Test loss: 2.285
# Step: 28250           	|	 Train loss: 1.117      	|	 Test loss: 2.285
# Step: 28300           	|	 Train loss: 1.117      	|	 Test loss: 2.285
# Step: 28350           	|	 Train loss: 1.117      	|	 Test loss: 2.285
# Step: 28400           	|	 Train loss: 1.116      	|	 Test loss: 2.285
# Step: 28450           	|	 Train loss: 1.116      	|	 Test loss: 2.285
# Step: 28500           	|	 Train loss: 1.116      	|	 Test loss: 2.286
# Step: 28550           	|	 Train loss: 1.116      	|	 Test loss: 2.286
# Step: 28600           	|	 Train loss: 1.116      	|	 Test loss: 2.286
# Step: 28650           	|	 Train loss: 1.116      	|	 Test loss: 2.286
# Step: 28700           	|	 Train loss: 1.116      	|	 Test loss: 2.286
# Step: 28750           	|	 Train loss: 1.116      	|	 Test loss: 2.286
# Step: 28800           	|	 Train loss: 1.116      	|	 Test loss: 2.286
# Step: 28850           	|	 Train loss: 1.116      	|	 Test loss: 2.286
# Step: 28900           	|	 Train loss: 1.116      	|	 Test loss: 2.286
# Step: 28950           	|	 Train loss: 1.116      	|	 Test loss: 2.287
# Step: 29000           	|	 Train loss: 1.116      	|	 Test loss: 2.287
# Step: 29050           	|	 Train loss: 1.116      	|	 Test loss: 2.287
# Step: 29100           	|	 Train loss: 1.116      	|	 Test loss: 2.287
# Step: 29150           	|	 Train loss: 1.116      	|	 Test loss: 2.287
# Step: 29200           	|	 Train loss: 1.116      	|	 Test loss: 2.287
# Step: 29250           	|	 Train loss: 1.116      	|	 Test loss: 2.287
# Step: 29300           	|	 Train loss: 1.116      	|	 Test loss: 2.287
# Step: 29350           	|	 Train loss: 1.116      	|	 Test loss: 2.287
# Step: 29400           	|	 Train loss: 1.116      	|	 Test loss: 2.287
# Step: 29450           	|	 Train loss: 1.116      	|	 Test loss: 2.288
# Step: 29500           	|	 Train loss: 1.116      	|	 Test loss: 2.288
# Step: 29550           	|	 Train loss: 1.116      	|	 Test loss: 2.288
# Step: 29600           	|	 Train loss: 1.116      	|	 Test loss: 2.288
# Step: 29650           	|	 Train loss: 1.116      	|	 Test loss: 2.288
# Step: 29700           	|	 Train loss: 1.116      	|	 Test loss: 2.288
# Step: 29750           	|	 Train loss: 1.116      	|	 Test loss: 2.288
# Step: 29800           	|	 Train loss: 1.116      	|	 Test loss: 2.288
# Step: 29850           	|	 Train loss: 1.116      	|	 Test loss: 2.288
# Step: 29900           	|	 Train loss: 1.116      	|	 Test loss: 2.288
# Step: 29950           	|	 Train loss: 1.116      	|	 Test loss: 2.288
# Step: 30000           	|	 Train loss: 1.116      	|	 Test loss: 2.289
# Step: 30050           	|	 Train loss: 1.116      	|	 Test loss: 2.289
# Step: 30100           	|	 Train loss: 1.116      	|	 Test loss: 2.289
# Step: 30150           	|	 Train loss: 1.116      	|	 Test loss: 2.289
# Step: 30200           	|	 Train loss: 1.116      	|	 Test loss: 2.289
# Step: 30250           	|	 Train loss: 1.116      	|	 Test loss: 2.289
# Step: 30300           	|	 Train loss: 1.116      	|	 Test loss: 2.289
# Step: 30350           	|	 Train loss: 1.116      	|	 Test loss: 2.289
# Step: 30400           	|	 Train loss: 1.116      	|	 Test loss: 2.289
# Step: 30450           	|	 Train loss: 1.116      	|	 Test loss: 2.289
# Step: 30500           	|	 Train loss: 1.116      	|	 Test loss: 2.289
# Step: 30550           	|	 Train loss: 1.116      	|	 Test loss: 2.290
# Step: 30600           	|	 Train loss: 1.116      	|	 Test loss: 2.290
# Step: 30650           	|	 Train loss: 1.116      	|	 Test loss: 2.290
# Step: 30700           	|	 Train loss: 1.116      	|	 Test loss: 2.290
# Step: 30750           	|	 Train loss: 1.116      	|	 Test loss: 2.290
# Step: 30800           	|	 Train loss: 1.116      	|	 Test loss: 2.290
# Step: 30850           	|	 Train loss: 1.116      	|	 Test loss: 2.290
# Step: 30900           	|	 Train loss: 1.116      	|	 Test loss: 2.290
# Step: 30950           	|	 Train loss: 1.116      	|	 Test loss: 2.290
# Step: 31000           	|	 Train loss: 1.116      	|	 Test loss: 2.290
# Step: 31050           	|	 Train loss: 1.116      	|	 Test loss: 2.290
# Step: 31100           	|	 Train loss: 1.116      	|	 Test loss: 2.290
# Step: 31150           	|	 Train loss: 1.116      	|	 Test loss: 2.291
# Step: 31200           	|	 Train loss: 1.116      	|	 Test loss: 2.291
# Step: 31250           	|	 Train loss: 1.116      	|	 Test loss: 2.291
# Step: 31300           	|	 Train loss: 1.116      	|	 Test loss: 2.291
# Step: 31350           	|	 Train loss: 1.116      	|	 Test loss: 2.291
# Step: 31400           	|	 Train loss: 1.116      	|	 Test loss: 2.291
# Step: 31450           	|	 Train loss: 1.116      	|	 Test loss: 2.291
# Step: 31500           	|	 Train loss: 1.116      	|	 Test loss: 2.291
# Step: 31550           	|	 Train loss: 1.116      	|	 Test loss: 2.291
# Step: 31600           	|	 Train loss: 1.116      	|	 Test loss: 2.291
# Step: 31650           	|	 Train loss: 1.116      	|	 Test loss: 2.291
# Step: 31700           	|	 Train loss: 1.116      	|	 Test loss: 2.291
# Step: 31750           	|	 Train loss: 1.116      	|	 Test loss: 2.292
# Step: 31800           	|	 Train loss: 1.116      	|	 Test loss: 2.292
# Step: 31850           	|	 Train loss: 1.116      	|	 Test loss: 2.292
# Step: 31900           	|	 Train loss: 1.116      	|	 Test loss: 2.292
# ...
# Step: 39550           	|	 Train loss: 0.187      	|	 Test loss: 2.681
# Step: 39600           	|	 Train loss: 0.186      	|	 Test loss: 2.681
# Step: 39650           	|	 Train loss: 0.186      	|	 Test loss: 2.681
# Step: 39700           	|	 Train loss: 0.186      	|	 Test loss: 2.681
# Step: 39750           	|	 Train loss: 0.186      	|	 Test loss: 2.681
# Step: 39800           	|	 Train loss: 0.186      	|	 Test loss: 2.681
# Step: 39850           	|	 Train loss: 0.186      	|	 Test loss: 2.681
# Step: 39900           	|	 Train loss: 0.186      	|	 Test loss: 2.681
# Step: 39950           	|	 Train loss: 0.185      	|	 Test loss: 2.681
# Step: 40000           	|	 Train loss: 0.185      	|	 Test loss: 2.681
# Step: 40050           	|	 Train loss: 0.185      	|	 Test loss: 2.681
# Step: 40100           	|	 Train loss: 0.185      	|	 Test loss: 2.681
# Step: 40150           	|	 Train loss: 0.185      	|	 Test loss: 2.681
# Step: 40200           	|	 Train loss: 0.185      	|	 Test loss: 2.681
# Step: 40250           	|	 Train loss: 0.185      	|	 Test loss: 2.681
# Step: 40300           	|	 Train loss: 0.184      	|	 Test loss: 2.681
# Step: 40350           	|	 Train loss: 0.184      	|	 Test loss: 2.681
# Step: 40400           	|	 Train loss: 0.184      	|	 Test loss: 2.681
# Step: 40450           	|	 Train loss: 0.184      	|	 Test loss: 2.681
# Step: 40500           	|	 Train loss: 0.184      	|	 Test loss: 2.681
# Step: 40550           	|	 Train loss: 0.184      	|	 Test loss: 2.681
# Step: 40600           	|	 Train loss: 0.184      	|	 Test loss: 2.681
# Step: 40650           	|	 Train loss: 0.183      	|	 Test loss: 2.681
# Step: 40700           	|	 Train loss: 0.183      	|	 Test loss: 2.681
# Step: 40750           	|	 Train loss: 0.183      	|	 Test loss: 2.681
# Step: 40800           	|	 Train loss: 0.183      	|	 Test loss: 2.681
# Step: 40850           	|	 Train loss: 0.183      	|	 Test loss: 2.681
# Step: 40900           	|	 Train loss: 0.183      	|	 Test loss: 2.681
# Step: 40950           	|	 Train loss: 0.182      	|	 Test loss: 2.681
# Step: 41000           	|	 Train loss: 0.182      	|	 Test loss: 2.680
# Step: 41050           	|	 Train loss: 0.182      	|	 Test loss: 2.680
# Step: 41100           	|	 Train loss: 0.182      	|	 Test loss: 2.680
# Step: 41150           	|	 Train loss: 0.182      	|	 Test loss: 2.680
# Step: 41200           	|	 Train loss: 0.182      	|	 Test loss: 2.680
# Step: 41250           	|	 Train loss: 0.181      	|	 Test loss: 2.680
# Step: 41300           	|	 Train loss: 0.181      	|	 Test loss: 2.680
# Step: 41350           	|	 Train loss: 0.181      	|	 Test loss: 2.680
# Step: 41400           	|	 Train loss: 0.181      	|	 Test loss: 2.680
# Step: 41450           	|	 Train loss: 0.181      	|	 Test loss: 2.680
# Step: 41500           	|	 Train loss: 0.180      	|	 Test loss: 2.680
# Step: 41550           	|	 Train loss: 0.180      	|	 Test loss: 2.680
# Step: 41600           	|	 Train loss: 0.180      	|	 Test loss: 2.680
# Step: 41650           	|	 Train loss: 0.180      	|	 Test loss: 2.680
# Step: 41700           	|	 Train loss: 0.180      	|	 Test loss: 2.680
# Step: 41750           	|	 Train loss: 0.180      	|	 Test loss: 2.680
# Step: 41800           	|	 Train loss: 0.179      	|	 Test loss: 2.680
# Step: 41850           	|	 Train loss: 0.179      	|	 Test loss: 2.680
# Step: 41900           	|	 Train loss: 0.179      	|	 Test loss: 2.680
# Step: 41950           	|	 Train loss: 0.179      	|	 Test loss: 2.680
# Step: 42000           	|	 Train loss: 0.178      	|	 Test loss: 2.679
# Step: 42050           	|	 Train loss: 0.178      	|	 Test loss: 2.679
# Step: 42100           	|	 Train loss: 0.178      	|	 Test loss: 2.679
# Step: 42150           	|	 Train loss: 0.178      	|	 Test loss: 2.679
# Step: 42200           	|	 Train loss: 0.178      	|	 Test loss: 2.679
# Step: 42250           	|	 Train loss: 0.177      	|	 Test loss: 2.679
# Step: 42300           	|	 Train loss: 0.177      	|	 Test loss: 2.679
# Step: 42350           	|	 Train loss: 0.177      	|	 Test loss: 2.679
# Step: 42400           	|	 Train loss: 0.177      	|	 Test loss: 2.679
# Step: 42450           	|	 Train loss: 0.176      	|	 Test loss: 2.679
# Step: 42500           	|	 Train loss: 0.176      	|	 Test loss: 2.679
# Step: 42550           	|	 Train loss: 0.176      	|	 Test loss: 2.678
# Step: 42600           	|	 Train loss: 0.175      	|	 Test loss: 2.678
# Step: 42650           	|	 Train loss: 0.175      	|	 Test loss: 2.678
# Step: 42700           	|	 Train loss: 0.175      	|	 Test loss: 2.678
# Step: 42750           	|	 Train loss: 0.174      	|	 Test loss: 2.678
# Step: 42800           	|	 Train loss: 0.174      	|	 Test loss: 2.678
# Step: 42850           	|	 Train loss: 0.174      	|	 Test loss: 2.678
# Step: 42900           	|	 Train loss: 0.173      	|	 Test loss: 2.678
# Step: 42950           	|	 Train loss: 0.173      	|	 Test loss: 2.677
# Step: 43000           	|	 Train loss: 0.173      	|	 Test loss: 2.677
# Step: 43050           	|	 Train loss: 0.172      	|	 Test loss: 2.677
# Step: 43100           	|	 Train loss: 0.172      	|	 Test loss: 2.677
# Step: 43150           	|	 Train loss: 0.171      	|	 Test loss: 2.677
# Step: 43200           	|	 Train loss: 0.171      	|	 Test loss: 2.677
# Step: 43250           	|	 Train loss: 0.170      	|	 Test loss: 2.676
# Step: 43300           	|	 Train loss: 0.170      	|	 Test loss: 2.676
# Step: 43350           	|	 Train loss: 0.169      	|	 Test loss: 2.676
# Step: 43400           	|	 Train loss: 0.169      	|	 Test loss: 2.676
# Step: 43450           	|	 Train loss: 0.168      	|	 Test loss: 2.676
# Step: 43500           	|	 Train loss: 0.167      	|	 Test loss: 2.675
# Step: 43550           	|	 Train loss: 0.166      	|	 Test loss: 2.675
# Step: 43600           	|	 Train loss: 0.165      	|	 Test loss: 2.675
# Step: 43650           	|	 Train loss: 0.165      	|	 Test loss: 2.675
# Step: 43700           	|	 Train loss: 0.164      	|	 Test loss: 2.675
# Step: 43750           	|	 Train loss: 0.163      	|	 Test loss: 2.674
# Step: 43800           	|	 Train loss: 0.162      	|	 Test loss: 2.674
# Step: 43850           	|	 Train loss: 0.162      	|	 Test loss: 2.674
# Step: 43900           	|	 Train loss: 0.161      	|	 Test loss: 2.674
# Step: 43950           	|	 Train loss: 0.161      	|	 Test loss: 2.674
# Step: 44000           	|	 Train loss: 0.161      	|	 Test loss: 2.673
# Step: 44050           	|	 Train loss: 0.161      	|	 Test loss: 2.673
# Step: 44100           	|	 Train loss: 0.160      	|	 Test loss: 2.673
# Step: 44150           	|	 Train loss: 0.160      	|	 Test loss: 2.673
# Step: 44200           	|	 Train loss: 0.160      	|	 Test loss: 2.673
# Step: 44250           	|	 Train loss: 0.160      	|	 Test loss: 2.673
# Step: 44300           	|	 Train loss: 0.160      	|	 Test loss: 2.672
# Step: 44350           	|	 Train loss: 0.160      	|	 Test loss: 2.672
# Step: 44400           	|	 Train loss: 0.159      	|	 Test loss: 2.672
# Step: 44450           	|	 Train loss: 0.159      	|	 Test loss: 2.672
# Step: 44500           	|	 Train loss: 0.159      	|	 Test loss: 2.672
# Step: 44550           	|	 Train loss: 0.159      	|	 Test loss: 2.672
# Step: 44600           	|	 Train loss: 0.159      	|	 Test loss: 2.671
# Step: 44650           	|	 Train loss: 0.159      	|	 Test loss: 2.671
# Step: 44700           	|	 Train loss: 0.159      	|	 Test loss: 2.671
# Step: 44750           	|	 Train loss: 0.159      	|	 Test loss: 2.671
# Step: 44800           	|	 Train loss: 0.158      	|	 Test loss: 2.671
# Step: 44850           	|	 Train loss: 0.158      	|	 Test loss: 2.671
# Step: 44900           	|	 Train loss: 0.158      	|	 Test loss: 2.671
# Step: 44950           	|	 Train loss: 0.158      	|	 Test loss: 2.670
# Step: 45000           	|	 Train loss: 0.158      	|	 Test loss: 2.670
# Step: 45050           	|	 Train loss: 0.158      	|	 Test loss: 2.670
# Step: 45100           	|	 Train loss: 0.158      	|	 Test loss: 2.670
# Step: 45150           	|	 Train loss: 0.158      	|	 Test loss: 2.670
# Step: 45200           	|	 Train loss: 0.157      	|	 Test loss: 2.670
# Step: 45250           	|	 Train loss: 0.157      	|	 Test loss: 2.670
# Step: 45300           	|	 Train loss: 0.157      	|	 Test loss: 2.670
# Step: 45350           	|	 Train loss: 0.157      	|	 Test loss: 2.669
# Step: 45400           	|	 Train loss: 0.157      	|	 Test loss: 2.669
# Step: 45450           	|	 Train loss: 0.157      	|	 Test loss: 2.669
# Step: 45500           	|	 Train loss: 0.157      	|	 Test loss: 2.669
# Step: 45550           	|	 Train loss: 0.157      	|	 Test loss: 2.669
# Step: 45600           	|	 Train loss: 0.156      	|	 Test loss: 2.669
# Step: 45650           	|	 Train loss: 0.156      	|	 Test loss: 2.669
# Step: 45700           	|	 Train loss: 0.156      	|	 Test loss: 2.669
# Step: 45750           	|	 Train loss: 0.156      	|	 Test loss: 2.669
# Step: 45800           	|	 Train loss: 0.156      	|	 Test loss: 2.669
# Step: 45850           	|	 Train loss: 0.156      	|	 Test loss: 2.669
# Step: 45900           	|	 Train loss: 0.156      	|	 Test loss: 2.668
# Step: 45950           	|	 Train loss: 0.156      	|	 Test loss: 2.668
# Step: 46000           	|	 Train loss: 0.155      	|	 Test loss: 2.668
# Step: 46050           	|	 Train loss: 0.155      	|	 Test loss: 2.668
# Step: 46100           	|	 Train loss: 0.155      	|	 Test loss: 2.668
# Step: 46150           	|	 Train loss: 0.155      	|	 Test loss: 2.668
# Step: 46200           	|	 Train loss: 0.155      	|	 Test loss: 2.668
# Step: 46250           	|	 Train loss: 0.155      	|	 Test loss: 2.668
# Step: 46300           	|	 Train loss: 0.155      	|	 Test loss: 2.668
# Step: 46350           	|	 Train loss: 0.155      	|	 Test loss: 2.668
# Step: 46400           	|	 Train loss: 0.154      	|	 Test loss: 2.668
# Step: 46450           	|	 Train loss: 0.154      	|	 Test loss: 2.668
# Step: 46500           	|	 Train loss: 0.154      	|	 Test loss: 2.668
# Step: 46550           	|	 Train loss: 0.154      	|	 Test loss: 2.668
# Step: 46600           	|	 Train loss: 0.154      	|	 Test loss: 2.668
# Step: 46650           	|	 Train loss: 0.154      	|	 Test loss: 2.668
# Step: 46700           	|	 Train loss: 0.154      	|	 Test loss: 2.668
# Step: 46750           	|	 Train loss: 0.153      	|	 Test loss: 2.668
# Step: 46800           	|	 Train loss: 0.153      	|	 Test loss: 2.668
# Step: 46850           	|	 Train loss: 0.153      	|	 Test loss: 2.668
# Step: 46900           	|	 Train loss: 0.153      	|	 Test loss: 2.668
# Step: 46950           	|	 Train loss: 0.153      	|	 Test loss: 2.668
# Step: 47000           	|	 Train loss: 0.153      	|	 Test loss: 2.668
# Step: 47050           	|	 Train loss: 0.153      	|	 Test loss: 2.668
# Step: 47100           	|	 Train loss: 0.152      	|	 Test loss: 2.668
# Step: 47150           	|	 Train loss: 0.152      	|	 Test loss: 2.668
# Step: 47200           	|	 Train loss: 0.152      	|	 Test loss: 2.668
# Step: 47250           	|	 Train loss: 0.152      	|	 Test loss: 2.668
# Step: 47300           	|	 Train loss: 0.152      	|	 Test loss: 2.668
# Step: 47350           	|	 Train loss: 0.152      	|	 Test loss: 2.668
# Step: 47400           	|	 Train loss: 0.151      	|	 Test loss: 2.668
# Step: 47450           	|	 Train loss: 0.151      	|	 Test loss: 2.668
# Step: 47500           	|	 Train loss: 0.151      	|	 Test loss: 2.668
# Step: 47550           	|	 Train loss: 0.151      	|	 Test loss: 2.668
# Step: 47600           	|	 Train loss: 0.151      	|	 Test loss: 2.668
# Step: 47650           	|	 Train loss: 0.151      	|	 Test loss: 2.668
# Step: 47700           	|	 Train loss: 0.151      	|	 Test loss: 2.668
# Step: 47750           	|	 Train loss: 0.150      	|	 Test loss: 2.668
# Step: 47800           	|	 Train loss: 0.150      	|	 Test loss: 2.668
# Step: 47850           	|	 Train loss: 0.150      	|	 Test loss: 2.668
# Step: 47900           	|	 Train loss: 0.150      	|	 Test loss: 2.668
# Step: 47950           	|	 Train loss: 0.150      	|	 Test loss: 2.668
# Step: 48000           	|	 Train loss: 0.150      	|	 Test loss: 2.668
# Step: 48050           	|	 Train loss: 0.149      	|	 Test loss: 2.668
# Step: 48100           	|	 Train loss: 0.149      	|	 Test loss: 2.668
# Step: 48150           	|	 Train loss: 0.149      	|	 Test loss: 2.668
# Step: 48200           	|	 Train loss: 0.149      	|	 Test loss: 2.668
# Step: 48250           	|	 Train loss: 0.149      	|	 Test loss: 2.668
# Step: 48300           	|	 Train loss: 0.149      	|	 Test loss: 2.668
# Step: 48350           	|	 Train loss: 0.148      	|	 Test loss: 2.668
# Step: 48400           	|	 Train loss: 0.148      	|	 Test loss: 2.668
# Step: 48450           	|	 Train loss: 0.148      	|	 Test loss: 2.668
# Step: 48500           	|	 Train loss: 0.148      	|	 Test loss: 2.668
# Step: 48550           	|	 Train loss: 0.148      	|	 Test loss: 2.668
# Step: 48600           	|	 Train loss: 0.147      	|	 Test loss: 2.668
# Step: 48650           	|	 Train loss: 0.147      	|	 Test loss: 2.668
# Step: 48700           	|	 Train loss: 0.147      	|	 Test loss: 2.668
# Step: 48750           	|	 Train loss: 0.147      	|	 Test loss: 2.668
# Step: 48800           	|	 Train loss: 0.147      	|	 Test loss: 2.668
# Step: 48850           	|	 Train loss: 0.146      	|	 Test loss: 2.668
# Step: 48900           	|	 Train loss: 0.146      	|	 Test loss: 2.668
# Step: 48950           	|	 Train loss: 0.146      	|	 Test loss: 2.668
# Step: 49000           	|	 Train loss: 0.146      	|	 Test loss: 2.669
# Step: 49050           	|	 Train loss: 0.146      	|	 Test loss: 2.669
# Step: 49100           	|	 Train loss: 0.145      	|	 Test loss: 2.669
# Step: 49150           	|	 Train loss: 0.145      	|	 Test loss: 2.669
# Step: 49200           	|	 Train loss: 0.145      	|	 Test loss: 2.669
# Step: 49250           	|	 Train loss: 0.145      	|	 Test loss: 2.669
# Step: 49300           	|	 Train loss: 0.145      	|	 Test loss: 2.669
# Step: 49350           	|	 Train loss: 0.144      	|	 Test loss: 2.669
# Step: 49400           	|	 Train loss: 0.144      	|	 Test loss: 2.669
# Step: 49450           	|	 Train loss: 0.144      	|	 Test loss: 2.669
# Step: 49500           	|	 Train loss: 0.144      	|	 Test loss: 2.670
# Step: 49550           	|	 Train loss: 0.144      	|	 Test loss: 2.670
# Step: 49600           	|	 Train loss: 0.143      	|	 Test loss: 2.670
# Step: 49650           	|	 Train loss: 0.143      	|	 Test loss: 2.670
# Step: 49700           	|	 Train loss: 0.143      	|	 Test loss: 2.670
# Step: 49750           	|	 Train loss: 0.143      	|	 Test loss: 2.670
# Step: 49800           	|	 Train loss: 0.142      	|	 Test loss: 2.670
# Step: 49850           	|	 Train loss: 0.142      	|	 Test loss: 2.670
# Step: 49900           	|	 Train loss: 0.142      	|	 Test loss: 2.671
# Step: 49950           	|	 Train loss: 0.142      	|	 Test loss: 2.671
# ----------------------------------------------------------------------------------------------------
# Time for rank 10: 934.17 sec
# Train loss: 0.14
# Test loss: 2.67
# ====================================================================================================
